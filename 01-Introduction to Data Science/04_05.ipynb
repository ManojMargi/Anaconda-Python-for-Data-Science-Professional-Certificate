# %%
# import pandas library 

import pandas as pd

# %%
# load the data from the csv file into a dataframe

us_babies = pd.read_csv("us_baby_names.csv")

# %%
# display the dataframe

us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
# slice out the rows containing your name
# save the resulting dataframe in a new variable

us_man = us_babies.loc[us_babies["Name"] == "Manoj", :]

# %%
# display the new dataframe

us_man
# Out:
#               Id   Name  Year Gender  Count
# 633228    633229  Manoj  1964      M      5
# 668508    668509  Manoj  1967      M      8
# 681376    681377  Manoj  1968      M      8
# 695028    695029  Manoj  1969      M      8
# 756736    756737  Manoj  1973      M      6
# 770874    770875  Manoj  1974      M     13
# 788417    788418  Manoj  1975      M      9
# 806078    806079  Manoj  1976      M      8
# 822775    822776  Manoj  1977      M     13
# 843460    843461  Manoj  1978      M      6
# 859769    859770  Manoj  1979      M     14
# 879430    879431  Manoj  1980      M     12
# 899387    899388  Manoj  1981      M     10
# 919414    919415  Manoj  1982      M      9
# 938151    938152  Manoj  1983      M     11
# 959930    959931  Manoj  1984      M      6
# 999809    999810  Manoj  1986      M      7
# 1022868  1022869  Manoj  1987      M      5
# 1042727  1042728  Manoj  1988      M      8
# 1067789  1067790  Manoj  1989      M      6
# 1168766  1168767  Manoj  1993      M      6
# 1193856  1193857  Manoj  1994      M      7
# 1274147  1274148  Manoj  1997      M      6
# 1360043  1360044  Manoj  2000      M      6
# 1388292  1388293  Manoj  2001      M      8
# 1418063  1418064  Manoj  2002      M      9
# 1451932  1451933  Manoj  2003      M      6
# 1622129  1622130  Manoj  2008      M      5

# %%
# create a horizontal bar plot that displays the counts of your name over the years

us_man.plot.barh(x = "Year", y = "Count")
# Out:
# <Axes: ylabel='Year'>

# %%
us_man.plot.bar(x = "Year", y = "Count");
